# %%
# dictionary

thisdict = {
   "brand" :"ford",
   "model" :"mustang",
    "year" : 1964
    }
print(thisdict)

# dictionary items:

thisdict = {
    "brand" :"ford",
   "model"  :"mustang",
    "year"  : 1964 
}
print(thisdict["brand"])
print(thisdict["model"])
print(thisdict["year"])


thisdict = {
    "brand" :"ford",
    "model"  :"mustang",
    "year"  : 1964 ,
    "year"  : 2020
} 
print(thisdict)
# Out:
# {'brand': 'ford', 'model': 'mustang', 'year': 1964}
# ford
# mustang
# 1964
# {'brand': 'ford', 'model': 'mustang', 'year': 2020}

# %%
# dictionary length()

thisdict = {
    "brand" :"ford",
    "model"  :"mustang",
    "year"  : 1964 ,
    "year"  : 2020
} 
print(len(thisdict))

# data type s()

thisdict = {
    "brand" :"ford",
    "model"  :"mustang",
    "year"  : 1964 ,
    "year"  : 2020
} 
print(type(thisdict))

# constructor dict()

thisdict = {
    "brand" :"ford",
    "model"  :"mustang",
    "year"  : 1964 ,
}
print((thisdict))


thisdict = dict(name = "venu", age = 22, country = "india")
print(thisdict)
# Out:
# 3
# <class 'dict'>
# {'brand': 'ford', 'model': 'mustang', 'year': 1964}
# {'name': 'venu', 'age': 22, 'country': 'india'}

# %%
# accssing items()

thisdict = {
    "brand" :"ford",
    "model"  :"mustang",
    "year"  : 1964 ,
}
x = thisdict["model"]
print(x)

thisdict = {
    "brand" :"ford",
    "model"  :"mustang",
    "year"  : 1964 ,
}
x = thisdict["brand"]
print(x)

thisdict = {
    "brand" :"ford",
    "model"  :"mustang",
    "year"  : 1964 ,
}
x = thisdict["year"]
print(x)
# Out:
# mustang
# ford
# 1964

# %%
# get()

thisdict = {
    "brand" :"ford",
    "model"  :"mustang",
    "year"  : 1964 ,
}
x = thisdict.get("year")
print(x)

thisdict = {
    "brand" :"ford",
    "model"  :"mustang",
    "year"  : 1964 ,
}
x = thisdict.get("model")
print(x)


thisdict = {
    "brand" :"ford",
    "model"  :"mustang",
    "year"  : 1964 ,
}
x = thisdict.get("brand")
print(x)
# Out:
# 1964
# mustang
# ford

# %%
# getkey()

thisdict = {
    "brand" :"ford",
    "model" :"mustang",
    "year"  : 1964 ,
}
x = thisdict.keys()
print(x)

car = {
    "brand" :"ford",
    "model" :"mustang",
    "year"  : 1964 ,
}
x = car.keys()
print(x)  # befere the change
car["color"] = "white"
print(x)   # after the change
# Out:
# dict_keys(['brand', 'model', 'year'])
# dict_keys(['brand', 'model', 'year'])
# dict_keys(['brand', 'model', 'year', 'color'])

# %%
# get values()

thisdict = {
    "brand" :"ford",
    "model" :"mustang",
    "year"  : 1964 ,
}
x = thisdict.values()
print(x)

car = {
    "brand" :"ford",
    "model" :"mustang",
    "year"  : 1964 ,
}
x =car.values()
print(x)  # befere the change
car["year"] = "2020"
print(x)   # after the change
# Out:
# dict_values(['ford', 'mustang', 1964])
# dict_values(['ford', 'mustang', 1964])
# dict_values(['ford', 'mustang', '2020'])

# %%
# get items()

thisdict = {
    "brand" :"ford",
    "model" :"mustang",
    "year"  : 1964 ,
}
x = thisdict.items()
print(x)

car = {
    "brand" :"ford",
    "model" :"mustang",
    "year"  : 1964 ,
}
x =car.items()
print(x)  # befere the change
car["year"] = "2020"
print(x)   # after the change
# Out:
# dict_items([('brand', 'ford'), ('model', 'mustang'), ('year', 1964)])
# dict_items([('brand', 'ford'), ('model', 'mustang'), ('year', 1964)])
# dict_items([('brand', 'ford'), ('model', 'mustang'), ('year', '2020')])

# %%
# if key exists()

thisdict = {
    "brand" :"ford",
    "model" :"mustang",
    "year"  : 1964 ,
}
if "model" in thisdict:
    
    print("yes, 'model' is one of the key thisdict dictionary")


thisdict = {
    "brand" :"ford",
    "model" :"mustang",
    "year"  : 1964 ,
}
if "tata" in thisdict:
    
    print("yes ,'tata' is one of the key thisdict dictionary")
# Out:
# yes, 'model' is one of the key thisdict dictionary

# %%
# dictionary methods()


# clear

car = {
    "brand" :"ford",
    "model" :"mustang",
    "year"  : 1964 ,
}

car.clear()
print(x) 


# copy()


car = {
    "brand" :"ford",
    "model" :"mustang",
    "year"  : 1964 ,
}
x = car.copy()
print(x)



# form keys()

x = ('key1','key2','key3')
y = 0
thisdict = dict.fromkeys(x,y)
print(thisdict)


x = ('key1','key2','key3')

thisdict = dict.fromkeys(x)
print(thisdict)

# get()


thisdict = {
    "brand" :"ford",
    "model" :"mustang",
    "year"  : 1964 ,
}
x = thisdict.get("model")
print(x)
x = thisdict.get("year")
print(x)
x = thisdict.get("brand")
print(x)


# items()


thisdict = {
    "brand" :"ford",
    "model" :"mustang",
    "year"  : 1964 ,
}
x = thisdict.items()
print(x)

# pop()

thisdict = {
    "brand" :"ford",
    "model" :"mustang",
    "year"  : 1964 ,
}
x = thisdict.pop("model")
print(thisdict)


car = {
    "brand" :"ford",
    "model" :"mustang",
    "year"  : 1964 ,
}
x = car.pop("year")
print(car)


#popitems()


car = {
    "brand" :"ford",
    "model" :"mustang",
    "year"  : 1964 ,
}

car.popitem()
print(car)

thisdict = {
    "brand" :"ford",
    "model" :"mustang",
    "year"  : 1964 ,
}

x = thisdict.popitem()
print(x)



# setdefault()


thisdict = {
    "brand" :"ford",
    "model" :"mustang",
    "year"  : 1964 ,
}

x = thisdict.setdefault("model","bronco")
print(x)


thisdict = {
    "brand" :"ford",
    "model" :"mustang",
    "year"  : 1964 ,
}

x = thisdict.setdefault("color","white")
print(x)


# update()


car = {
    "brand" :"ford",
    "model" :"mustang",
    "year"  : 1964 ,
}

car.update({"color":"white"})
print(car)


# values()


thisdict = {
    "brand" :"ford",
    "model" :"mustang",
    "year"  : 1964 ,
}

x = thisdict.values()
print(thisdict)



thisdict = {
    "brand" :"ford",
    "model" :"mustang",
    "year"  : 1964 ,
}

x = thisdict.values()
thisdict["year"] = 2018
print(x)
# Out:
# dict_values(['ford', 'mustang', 1964])
# {'brand': 'ford', 'model': 'mustang', 'year': 1964}
# {'key1': 0, 'key2': 0, 'key3': 0}
# {'key1': None, 'key2': None, 'key3': None}
# mustang
# 1964
# ford
# dict_items([('brand', 'ford'), ('model', 'mustang'), ('year', 1964)])
# {'brand': 'ford', 'year': 1964}
# {'brand': 'ford', 'model': 'mustang'}
# {'brand': 'ford', 'model': 'mustang'}
# ('year', 1964)
# mustang
# white
# {'brand': 'ford', 'model': 'mustang', 'year': 1964, 'color': 'white'}
# {'brand': 'ford', 'model': 'mustang', 'year': 1964}
# dict_values(['ford', 'mustang', 2018])
